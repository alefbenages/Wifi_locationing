# %% [markdown]
# # Task 3: Evaluate Techniques for Wifi Locationing

# %% [markdown]
# # 00_EDA

# %% [markdown]
# # Import libraries

# %%
# basic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
path = '/home/ale/Dropbox/UBIQUM/4.DeepAnalytics&Visualization/T4M3.WiFiLocationing/Data/UJIndoorLoc/'
file = 'TestData.csv'

Test = pd.read_csv(path + file)

Test.head(3)
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520    LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7515.916799  4.864890e+06      1           1        0
# 1     100  ...     100 -7383.867221  4.864840e+06      4           2        0
# 2     100  ...     100 -7374.302080  4.864847e+06      4           2        0
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 0                 0       0        0  1380872703
# 1                 0       0       13  1381155054
# 2                 0       0       13  1381155095
#
# [3 rows x 529 columns]

# %%
path = '/home/ale/Dropbox/UBIQUM/4.DeepAnalytics&Visualization/T4M3.WiFiLocationing/Data/UJIndoorLoc/'
file = 'trainingData.csv'

Train = pd.read_csv(path + file)

Train.head(3)
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 0                 2       2       23  1371713733
# 1                 2       2       23  1371713691
# 2                 2       2       23  1371714095
#
# [3 rows x 529 columns]

# %%
print("TestData  dimensions: ", Test.shape)
print("TrainData  dimensions: ", Train.shape)
# Out:
# TestData  dimensions:  (1111, 529)
# TrainData  dimensions:  (19937, 529)

# %%
Train_cols = Train.columns
Test_cols = Test.columns

print(Train_cols.difference(Test_cols))
# Out:
# Index([], dtype='object')

# %% [markdown]
# - Train has arround 17x more data than test, seems good
# - and both DF's have the same columns names (there are no differences)

# %% [markdown]
# # Nulls?

# %%
# The any() function returns True if any item in an iterable are true, otherwise it returns False
print("Null values on Train data?:", any(Train.isnull().sum()))
print("Null values on Test  data?:", any(Test.isnull().sum()))
# Out:
# Null values on Train data?: False
# Null values on Test  data?: False

# %% [markdown]
# # DataTypes

# %% [markdown]
# ## Test

# %%
DT_Test = Test.iloc[:,520:529].dtypes

DT_Test
# Out:
# LONGITUDE           float64
# LATITUDE            float64
# FLOOR                 int64
# BUILDINGID            int64
# SPACEID               int64
# RELATIVEPOSITION      int64
# USERID                int64
# PHONEID               int64
# TIMESTAMP             int64
# dtype: object

# %% [markdown]
# ## Train

# %%
DT_Train = Train.iloc[:,520:529].dtypes

DT_Train
# Out:
# LONGITUDE           float64
# LATITUDE            float64
# FLOOR                 int64
# BUILDINGID            int64
# SPACEID               int64
# RELATIVEPOSITION      int64
# USERID                int64
# PHONEID               int64
# TIMESTAMP             int64
# dtype: object

# %% [markdown]
# # Describe

# %% [markdown]
# ## Test

# %%
Test.describe()
# Out:
#             WAP001  WAP002       WAP003       WAP004  WAP005  WAP006  WAP007  \
# count  1111.000000  1111.0  1111.000000  1111.000000  1111.0  1111.0  1111.0
# mean     98.627363   100.0    99.665167    99.665167   100.0   100.0   100.0
# std      16.127245     0.0     7.888265     7.888607     0.0     0.0     0.0
# min     -94.000000   100.0   -87.000000   -88.000000   100.0   100.0   100.0
# 25%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# 50%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# 75%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# max     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
#
#             WAP008       WAP009       WAP010  ...       WAP520    LONGITUDE  \
# count  1111.000000  1111.000000  1111.000000  ...  1111.000000  1111.000000
# mean     94.297030    90.655266    98.811881  ...    99.843384 -7529.197448
# ...

# %% [markdown]
# ## Train

# %%
Test.describe()
# Out:
#             WAP001  WAP002       WAP003       WAP004  WAP005  WAP006  WAP007  \
# count  1111.000000  1111.0  1111.000000  1111.000000  1111.0  1111.0  1111.0
# mean     98.627363   100.0    99.665167    99.665167   100.0   100.0   100.0
# std      16.127245     0.0     7.888265     7.888607     0.0     0.0     0.0
# min     -94.000000   100.0   -87.000000   -88.000000   100.0   100.0   100.0
# 25%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# 50%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# 75%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# max     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
#
#             WAP008       WAP009       WAP010  ...       WAP520    LONGITUDE  \
# count  1111.000000  1111.000000  1111.000000  ...  1111.000000  1111.000000
# mean     94.297030    90.655266    98.811881  ...    99.843384 -7529.197448
# ...

# %%
1030 1330  Av. Rasols de peguera 232, ateneu de Fabricaciò
