# %% [markdown]
# # Task 3: Evaluate Techniques for Wifi Locationing

# %% [markdown]
# # 0_PREPROCESSING

# %% [markdown]
# # Import libraries

# %%
# basic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
path = '/home/ale/Dropbox/UBIQUM/4.DeepAnalytics&Visualization/T4M3.WiFiLocationing/Data/UJIndoorLoc/'
file = 'TestData.csv'

Val_data = pd.read_csv(path + file)

Val_data.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520    LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7515.916799  4.864890e+06      1           1        0
# 1     100  ...     100 -7383.867221  4.864840e+06      4           2        0
# 2     100  ...     100 -7374.302080  4.864847e+06      4           2        0
# 3     100  ...     100 -7365.824883  4.864843e+06      4           2        0
# 4     100  ...     100 -7641.499303  4.864922e+06      2           0        0
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 0                 0       0        0  1380872703
# 1                 0       0       13  1381155054
# 2                 0       0       13  1381155095
# 3                 0       0       13  1381155138
# 4                 0       0        2  1380877774
#
# [5 rows x 529 columns]

# %%
Val_data.shape
# Out:
# (1111, 529)

# %% [markdown]
# ## Nulls?

# %%
# The any() function returns True if any item in an iterable are true, otherwise it returns False
print(any(Val_data.isnull().sum()))
# Out:
# False

# %% [markdown]
# We already check for null values, but you can verify this visually by applying a heat map.
# there are a lot of features,and heatmap cant print them all... but you can get an idea.

# %%
# simple heat map showing where we are missing data
heat_map = sns.heatmap(Val_data.isnull(), yticklabels = False, cbar = True, cmap = "PuRd", vmin = 0, vmax = 0.1)
plt.show()

# %% [markdown]
# DataTypes

# %%
Val_data.iloc[:,519:529].dtypes
# Out:
# WAP520                int64
# LONGITUDE           float64
# LATITUDE            float64
# FLOOR                 int64
# BUILDINGID            int64
# SPACEID               int64
# RELATIVEPOSITION      int64
# USERID                int64
# PHONEID               int64
# TIMESTAMP             int64
# dtype: object

# %%
Val_data.describe()
# Out:
#             WAP001  WAP002       WAP003       WAP004  WAP005  WAP006  WAP007  \
# count  1111.000000  1111.0  1111.000000  1111.000000  1111.0  1111.0  1111.0
# mean     98.627363   100.0    99.665167    99.665167   100.0   100.0   100.0
# std      16.127245     0.0     7.888265     7.888607     0.0     0.0     0.0
# min     -94.000000   100.0   -87.000000   -88.000000   100.0   100.0   100.0
# 25%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# 50%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# 75%     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
# max     100.000000   100.0   100.000000   100.000000   100.0   100.0   100.0
#
#             WAP008       WAP009       WAP010  ...       WAP520    LONGITUDE  \
# count  1111.000000  1111.000000  1111.000000  ...  1111.000000  1111.000000
# mean     94.297030    90.655266    98.811881  ...    99.843384 -7529.197448
# std      32.148809    39.886991    14.931667  ...     5.220261   120.209336
# min     -99.000000   -96.000000   -98.000000  ...   -74.000000 -7695.938755
# 25%     100.000000   100.000000   100.000000  ...   100.000000 -7637.423800
# 50%     100.000000   100.000000   100.000000  ...   100.000000 -7560.376300
# 75%     100.000000   100.000000   100.000000  ...   100.000000 -7420.539659
# max     100.000000   100.000000   100.000000  ...   100.000000 -7299.786517
#
#            LATITUDE        FLOOR   BUILDINGID  SPACEID  RELATIVEPOSITION  \
# count  1.111000e+03  1111.000000  1111.000000   1111.0            1111.0
# mean   4.864902e+06     1.571557     0.758776      0.0               0.0
# std    7.027280e+01     1.001828     0.816139      0.0               0.0
# min    4.864748e+06     0.000000     0.000000      0.0               0.0
# 25%    4.864843e+06     1.000000     0.000000      0.0               0.0
# 50%    4.864915e+06     1.000000     1.000000      0.0               0.0
# 75%    4.864967e+06     2.000000     1.000000      0.0               0.0
# max    4.865017e+06     4.000000     2.000000      0.0               0.0
#
#        USERID      PHONEID     TIMESTAMP
# count  1111.0  1111.000000  1.111000e+03
# mean      0.0    11.923492  1.380604e+09
# std       0.0     6.556236  5.003222e+05
# min       0.0     0.000000  1.379578e+09
# 25%       0.0     9.000000  1.380189e+09
# 50%       0.0    13.000000  1.380873e+09
# 75%       0.0    15.000000  1.380875e+09
# max       0.0    21.000000  1.381248e+09
#
# [8 rows x 529 columns]

# %% [markdown]
# ## get an idea of the possible WAP values
#
# Seems that the great majority of values of singal strenght is +100 (out of range), a possible way to ignore those values is replace them by a np.nan, as they are not considered in a plot.  A copy of the dataframe will be done...

# %%
# Take a random sample of the original dataframe and make a copy
Val_dataPossibleValues = Val_data.sample(frac =.10, random_state= 200)    # .10 menans takes samples by the 10% of the dataset

# %%
Val_dataPossibleValues = Val_dataPossibleValues.drop(['LONGITUDE', 'LATITUDE', 'FLOOR', 'BUILDINGID', 'SPACEID',
       'RELATIVEPOSITION', 'USERID', 'PHONEID', 'TIMESTAMP'], axis = 1)

# %%
Val_dataPossibleValues = Val_dataPossibleValues.replace([100],np.nan)
Val_dataPossibleValues.head()
# Out:
#      WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 636     NaN     NaN     NaN     NaN     NaN     NaN     NaN   -95.0     NaN
# 64      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 463     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 820     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 107     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      WAP010  ...  WAP511  WAP512  WAP513  WAP514  WAP515  WAP516  WAP517  \
# 636     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 64      NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 463     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 820     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 107     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      WAP518  WAP519  WAP520
# 636     NaN     NaN     NaN
# 64      NaN     NaN     NaN
# 463     NaN     NaN     NaN
# 820     NaN     NaN     NaN
# 107     NaN     NaN     NaN
#
# [5 rows x 520 columns]

# %%
plt.hist(Val_dataPossibleValues, bins = 10)
plt.show();
# Out:
# /home/ale/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py:6623: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /home/ale/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py:6624: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))

# %% [markdown]
# a bit of zoom always help

# %%
plt.hist(Val_dataPossibleValues, bins = 10)
plt.xlim(-100,-60)
plt.show;

# %% [markdown]
# it's not a randomized sample, just the first 100 hundred rows, but we can get an idea that the most possiblle values are arround -90dB.

# %% [markdown]
# ## OUTPUT VARIABLES
# the main objective of the project is to use signal strenght to guess the location of the cellphones.
#
# So our outputs are the location variables:
# - **FLOOR, BUILDING, LAT, LONG**.

# %% [markdown]
# ### FLOOR

# %%
# use plt.bar instead of plt.hist because it can use align='center'. Also removes the float values from the Xaxis
labels, counts = np.unique(Val_data['FLOOR'], return_counts=True)

plt.bar(labels, counts, align='center')
plt.gca().set_xticks(labels)

plt.show()

# %% [markdown]
# - Umbalanced data, there are a lot of datapoints from FLOORS 0 to 3, and only a few of 4.
# - Perhaps this happends because not all the building have 4 floors. In fact, only BuildingID = 2 has 4 floors.

# %% [markdown]
# ### BUILDING ID

# %%
labels, counts = np.unique(Val_data["BUILDINGID"], return_counts=True)

plt.bar(labels, counts, align='center')
plt.gca().set_xticks(labels)

plt.show()

# %% [markdown]
# - again, quite umbalanced data. Most of data comes from the BuildingID = 2

# %%
# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”
sns.jointplot(x=Val_data['FLOOR'], y=Val_data['BUILDINGID'], kind='hex')

plt.show()

# %% [markdown]
# it's interesting to combine Floor/Building.
# - most of data was collected from buildingID=2. and this is the only one with 4 floors.

# %% [markdown]
# ### LATITUDE AND LONGITUDE

# %%
plt.hist(Val_data["LONGITUDE"], bins = 100)
plt.show()

# %%
plt.hist(Val_data["LATITUDE"], bins = 50)
plt.show()

# %% [markdown]
# # Save Data

# %%
path = '/home/ale/Dropbox/UBIQUM/4.DeepAnalytics&Visualization/T4M3.WiFiLocationing/Data/'
file = "0_DataPrepro_Test.csv"

Val_data.to_csv(path + file, index = False)

# load to check how it's saved
Saved_Val_data = pd.read_csv(path + file)

Saved_Val_data.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520    LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7515.916799  4.864890e+06      1           1        0
# 1     100  ...     100 -7383.867221  4.864840e+06      4           2        0
# 2     100  ...     100 -7374.302080  4.864847e+06      4           2        0
# 3     100  ...     100 -7365.824883  4.864843e+06      4           2        0
# 4     100  ...     100 -7641.499303  4.864922e+06      2           0        0
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# 0                 0       0        0  1380872703
# 1                 0       0       13  1381155054
# 2                 0       0       13  1381155095
# 3                 0       0       13  1381155138
# 4                 0       0        2  1380877774
#
# [5 rows x 529 columns]

# %% [markdown]
# # Data to Building

# %% [markdown]
# ## 1.1 Keep Usefull features

# %%
# make a copy of the dataset, keeping only the predictor/predicted features
Vdata_Building = Val_data.drop(columns = ['LONGITUDE', 'LATITUDE', 'FLOOR', 'SPACEID','RELATIVEPOSITION', 'USERID', 'PHONEID', 'TIMESTAMP'])

Vdata_Building.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP512  WAP513  WAP514  WAP515  WAP516  WAP517  WAP518  \
# 0     100  ...     100     100     100     100     100     100     100
# 1     100  ...     100     100     100     100     100     100     100
# 2     100  ...     100     100     100     100     100     100     100
# 3     100  ...     100     100     100     100     100     100     100
# 4     100  ...     100     100     100     100     100     100     100
#
#    WAP519  WAP520  BUILDINGID
# 0     100     100           1
# 1     100     100           2
# 2     100     100           2
# 3     100     100           2
# 4     100     100           0
#
# [5 rows x 521 columns]

# %% [markdown]
# ## 1.2 Dummify
#
# In this case it's not needed, because i'm using all numerical variables to predict a categorical variable.

# %% [markdown]
# ## 1.3 Sample Data
#
# As there is a lot of data, is a good idea to fail faster with a reduced proportion of the data

# %%
#sample =  Vdata_Building

# %%
Vdata_Building = sample.sample(frac =1, random_state= 200)

print("Len of the DF :" + str(len(Vdata_Building)))

#Tdata_Building.head()
# Out:
# Len of the DF :1111

# %% [markdown]
# ## 1.4 X/y Split

# %%
X_Vd_building = Vdata_Building.iloc[:,0:520]
y_Vd_building = Vdata_Building.iloc[:,520:521]

X_Vd_building.head() # check predictors
# Out:
#      WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 636     100     100     100     100     100     100     100     -95     100
# 64      100     100     100     100     100     100     100     100     100
# 463     100     100     100     100     100     100     100     100     100
# 820     100     100     100     100     100     100     100     100     100
# 107     100     100     100     100     100     100     100     100     100
#
#      WAP010  ...  WAP511  WAP512  WAP513  WAP514  WAP515  WAP516  WAP517  \
# 636     100  ...     100     100     100     100     100     100     100
# 64      100  ...     100     100     100     100     100     100     100
# 463     100  ...     100     100     100     100     100     100     100
# 820     100  ...     100     100     100     100     100     100     100
# 107     100  ...     100     100     100     100     100     100     100
#
#      WAP518  WAP519  WAP520
# 636     100     100     100
# 64      100     100     100
# 463     100     100     100
# 820     100     100     100
# 107     100     100     100
#
# [5 rows x 520 columns]

# %%
y_Vd_building.head() # check predicted
# Out:
#      BUILDINGID
# 636           0
# 64            0
# 463           0
# 820           1
# 107           0

# %% [markdown]
# ## 1.5 Save PreProcessed Data

# %%
path = '/home/ale/Dropbox/UBIQUM/4.DeepAnalytics&Visualization/T4M3.WiFiLocationing/Data/'
file_X = "1_Val_DataPrepro_Building_X.csv"
file_y = "1_Val_DataPrepro_Building_y.csv"

X_Vd_building.to_csv(path + file_X, index = False)
y_Vd_building.to_csv(path + file_y, index = False)

# %% [markdown]
# # Data To Floor

# %% [markdown]
# ## 2.1 Keep Usefull features

# %%
# make a copy of the dataset, keeping only the predictor/predicted features
Vdata_Floor = Val_data.drop(columns = ['LONGITUDE', 'LATITUDE', 'SPACEID', 'RELATIVEPOSITION', 'USERID', 'PHONEID', 'TIMESTAMP'])

#Vdata_Floor.head()

# %% [markdown]
# ## 2.2 Dummify
#
# Now, as there is a categorical variable that will be used as a predictor (input) is important to dummify (binarize) it.

# %%
Vdata_Floor = pd.get_dummies(Vdata_Floor, columns = ['BUILDINGID'])
Vdata_Floor.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP515  WAP516  WAP517  WAP518  WAP519  WAP520  FLOOR  \
# 0     100  ...     100     100     100     100     100     100      1
# 1     100  ...     100     100     100     100     100     100      4
# 2     100  ...     100     100     100     100     100     100      4
# 3     100  ...     100     100     100     100     100     100      4
# 4     100  ...     100     100     100     100     100     100      2
#
#    BUILDINGID_0  BUILDINGID_1  BUILDINGID_2
# 0             0             1             0
# 1             0             0             1
# 2             0             0             1
# 3             0             0             1
# 4             1             0             0
#
# [5 rows x 524 columns]

# %% [markdown]
# ## 2.3 Sample Data
#
# As there is a lot of data, is a good idea to fail faster with a reduced proportion of the data

# %%
sample =  Vdata_Floor

# %%
Vdata_Floor = sample.sample(frac =1, random_state= 200)

print("Len of the DF :" + str(len(Vdata_Floor)))

#Tdata_Building.head()
# Out:
# Len of the DF :1111

# %% [markdown]
# ## 2.4 X/y Split

# %%
y_Vd_floor = Vdata_Floor.iloc[:,520:521]
X_Vd_floor = Vdata_Floor.drop(columns = ['FLOOR'])


X_Vd_floor.head() # check predictors
# Out:
#      WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 636     100     100     100     100     100     100     100     -95     100
# 64      100     100     100     100     100     100     100     100     100
# 463     100     100     100     100     100     100     100     100     100
# 820     100     100     100     100     100     100     100     100     100
# 107     100     100     100     100     100     100     100     100     100
#
#      WAP010  ...  WAP514  WAP515  WAP516  WAP517  WAP518  WAP519  WAP520  \
# 636     100  ...     100     100     100     100     100     100     100
# 64      100  ...     100     100     100     100     100     100     100
# 463     100  ...     100     100     100     100     100     100     100
# 820     100  ...     100     100     100     100     100     100     100
# 107     100  ...     100     100     100     100     100     100     100
#
#      BUILDINGID_0  BUILDINGID_1  BUILDINGID_2
# 636             1             0             0
# 64              1             0             0
# 463             1             0             0
# 820             0             1             0
# 107             1             0             0
#
# [5 rows x 523 columns]

# %%
y_Vd_floor.head() # check predicted
# Out:
#      FLOOR
# 636      2
# 64       0
# 463      2
# 820      2
# 107      0

# %% [markdown]
# ## 2.5 Save PreProcessed Data

# %%
path = '/home/ale/Dropbox/UBIQUM/4.DeepAnalytics&Visualization/T4M3.WiFiLocationing/Data/'
file_X = "2_Val_DataPrepro_Floor_X.csv"
file_y = "2_Val_DataPrepro_Floor_y.csv"

X_Vd_building.to_csv(path + file_X, index = False)
y_Vd_building.to_csv(path + file_y, index = False)

# %% [markdown]
# # Data to Latitude

# %% [markdown]
# ## 3.1 Keep Usefull features

# %%
# make a copy of the dataset, keeping only the predictor/predicted features
Vdata_LAT = Val_data.drop(columns = ['LONGITUDE', 'SPACEID', 'RELATIVEPOSITION', 'USERID', 'PHONEID', 'TIMESTAMP'])

Vdata_LAT.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP514  WAP515  WAP516  WAP517  WAP518  WAP519  WAP520  \
# 0     100  ...     100     100     100     100     100     100     100
# 1     100  ...     100     100     100     100     100     100     100
# 2     100  ...     100     100     100     100     100     100     100
# 3     100  ...     100     100     100     100     100     100     100
# 4     100  ...     100     100     100     100     100     100     100
#
#        LATITUDE  FLOOR  BUILDINGID
# 0  4.864890e+06      1           1
# 1  4.864840e+06      4           2
# 2  4.864847e+06      4           2
# 3  4.864843e+06      4           2
# 4  4.864922e+06      2           0
#
# [5 rows x 523 columns]

# %% [markdown]
# ### 3.2 Dummify
#
# Now, as there is a categorical variable that will be used as a predictor (input) is important to dummify (binarize) it.

# %%
Vdata_LAT = pd.get_dummies(Vdata_LAT, columns = ['BUILDINGID', 'FLOOR'])
Vdata_LAT.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520      LATITUDE  BUILDINGID_0  BUILDINGID_1  \
# 0     100  ...     100  4.864890e+06             0             1
# 1     100  ...     100  4.864840e+06             0             0
# 2     100  ...     100  4.864847e+06             0             0
# 3     100  ...     100  4.864843e+06             0             0
# 4     100  ...     100  4.864922e+06             1             0
#
#    BUILDINGID_2  FLOOR_0  FLOOR_1  FLOOR_2  FLOOR_3  FLOOR_4
# 0             0        0        1        0        0        0
# 1             1        0        0        0        0        1
# 2             1        0        0        0        0        1
# 3             1        0        0        0        0        1
# 4             0        0        0        1        0        0
#
# [5 rows x 529 columns]

# %% [markdown]
# ## 3.3 Sample Data
#
# As there is a lot of data, is a good idea to fail faster with a reduced proportion of the data

# %%
sample = Vdata_LAT

# %%
Vdata_LAT = sample.sample(frac =1, random_state= 200)

print("Len of the DF :" + str(len(Vdata_LAT)))

#Tdata_Building.head()
# Out:
# Len of the DF :1111

# %% [markdown]
# ## 3.4 X/y Split
#
# - Input  > WAPS[0..520), BUILDINGID, FLOOR
# - Output > LAT

# %%
y_Vd_lat = Vdata_LAT.iloc[:,520:521]
X_Vd_lat = Vdata_LAT.drop(columns = ['LATITUDE'])


X_Vd_lat.head() # check predictors
# Out:
#      WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 636     100     100     100     100     100     100     100     -95     100
# 64      100     100     100     100     100     100     100     100     100
# 463     100     100     100     100     100     100     100     100     100
# 820     100     100     100     100     100     100     100     100     100
# 107     100     100     100     100     100     100     100     100     100
#
#      WAP010  ...  WAP519  WAP520  BUILDINGID_0  BUILDINGID_1  BUILDINGID_2  \
# 636     100  ...     100     100             1             0             0
# 64      100  ...     100     100             1             0             0
# 463     100  ...     100     100             1             0             0
# 820     100  ...     100     100             0             1             0
# 107     100  ...     100     100             1             0             0
#
#      FLOOR_0  FLOOR_1  FLOOR_2  FLOOR_3  FLOOR_4
# 636        0        0        1        0        0
# 64         1        0        0        0        0
# 463        0        0        1        0        0
# 820        0        0        1        0        0
# 107        1        0        0        0        0
#
# [5 rows x 528 columns]

# %%
y_Vd_lat.head() # check predicted
# Out:
#          LATITUDE
# 636  4.864987e+06
# 64   4.864933e+06
# 463  4.864935e+06
# 820  4.864863e+06
# 107  4.864999e+06

# %% [markdown]
# ## 3.5 Save PreProcessed Data

# %%
path = '/home/ale/Dropbox/UBIQUM/4.DeepAnalytics&Visualization/T4M3.WiFiLocationing/Data/'
file_X = "3_Val_DataPrepro_LAT_X.csv"
file_y = "3_Val_DataPrepro_LAT_y.csv"

X_Vd_building.to_csv(path + file_X, index = False)
y_Vd_building.to_csv(path + file_y, index = False)

# %% [markdown]
# # Data to Longitude

# %% [markdown]
# ## 4.1 Keep Usefull features

# %%
# make a copy of the dataset, keeping only the predictor/predicted features
Vdata_LON = Val_data.drop(columns = ['SPACEID', 'RELATIVEPOSITION', 'USERID', 'PHONEID', 'TIMESTAMP'])

Vdata_LON.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP515  WAP516  WAP517  WAP518  WAP519  WAP520    LONGITUDE  \
# 0     100  ...     100     100     100     100     100     100 -7515.916799
# 1     100  ...     100     100     100     100     100     100 -7383.867221
# 2     100  ...     100     100     100     100     100     100 -7374.302080
# 3     100  ...     100     100     100     100     100     100 -7365.824883
# 4     100  ...     100     100     100     100     100     100 -7641.499303
#
#        LATITUDE  FLOOR  BUILDINGID
# 0  4.864890e+06      1           1
# 1  4.864840e+06      4           2
# 2  4.864847e+06      4           2
# 3  4.864843e+06      4           2
# 4  4.864922e+06      2           0
#
# [5 rows x 524 columns]

# %% [markdown]
# ### 4.2 Dummify

# %%
Vdata_LON = pd.get_dummies(Vdata_LON, columns = ['BUILDINGID', 'FLOOR'])
Vdata_LON.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     100     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...    LONGITUDE      LATITUDE  BUILDINGID_0  BUILDINGID_1  \
# 0     100  ... -7515.916799  4.864890e+06             0             1
# 1     100  ... -7383.867221  4.864840e+06             0             0
# 2     100  ... -7374.302080  4.864847e+06             0             0
# 3     100  ... -7365.824883  4.864843e+06             0             0
# 4     100  ... -7641.499303  4.864922e+06             1             0
#
#    BUILDINGID_2  FLOOR_0  FLOOR_1  FLOOR_2  FLOOR_3  FLOOR_4
# 0             0        0        1        0        0        0
# 1             1        0        0        0        0        1
# 2             1        0        0        0        0        1
# 3             1        0        0        0        0        1
# 4             0        0        0        1        0        0
#
# [5 rows x 530 columns]

# %% [markdown]
# ## 4.3 Sample Data
#
# As there is a lot of data, is a good idea to fail faster with a reduced proportion of the data

# %%
sample = Vdata_LON

# %%
Vdata_LON = sample.sample(frac =1, random_state= 200)

print("Len of the DF :" + str(len(Vdata_LON)))

#Tdata_Building.head()
# Out:
# Len of the DF :1111

# %% [markdown]
# ## 4.4 X/y Split
#
# - Input  > WAPS[0..520), BUILDINGID, FLOOR, LAT
# - Output > LON

# %%
y_Vd_lon = Vdata_LON.iloc[:,520:521]
X_Vd_lon = Vdata_LON.drop(columns = ['LONGITUDE'])


X_Vd_lon.head() # check predictors
# Out:
#      WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 636     100     100     100     100     100     100     100     -95     100
# 64      100     100     100     100     100     100     100     100     100
# 463     100     100     100     100     100     100     100     100     100
# 820     100     100     100     100     100     100     100     100     100
# 107     100     100     100     100     100     100     100     100     100
#
#      WAP010  ...  WAP520      LATITUDE  BUILDINGID_0  BUILDINGID_1  \
# 636     100  ...     100  4.864987e+06             1             0
# 64      100  ...     100  4.864933e+06             1             0
# 463     100  ...     100  4.864935e+06             1             0
# 820     100  ...     100  4.864863e+06             0             1
# 107     100  ...     100  4.864999e+06             1             0
#
#      BUILDINGID_2  FLOOR_0  FLOOR_1  FLOOR_2  FLOOR_3  FLOOR_4
# 636             0        0        0        1        0        0
# 64              0        1        0        0        0        0
# 463             0        0        0        1        0        0
# 820             0        0        0        1        0        0
# 107             0        1        0        0        0        0
#
# [5 rows x 529 columns]

# %%
y_Vd_lon.head() # check predicted
# Out:
#        LONGITUDE
# 636 -7587.539083
# 64  -7682.455650
# 463 -7676.753700
# 820 -7507.640600
# 107 -7639.109633

# %% [markdown]
# ## 4.5 Save PreProcessed Data

# %%
path = '/home/ale/Dropbox/UBIQUM/4.DeepAnalytics&Visualization/T4M3.WiFiLocationing/Data/'
file_X = "4_Val_DataPrepro_LON_X.csv"
file_y = "4_Val_DataPrepro_LON_y.csv"

X_Vd_building.to_csv(path + file_X, index = False)
y_Vd_building.to_csv(path + file_y, index = False)
